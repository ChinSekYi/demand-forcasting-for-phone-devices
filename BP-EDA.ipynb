# %% [markdown]
# # Predicting Company Bankruptcy using Machine Learning

# %% [markdown]
# ## Table of Contents
# 1. [Problem Statement](#1-problem-statement)
# 2. [Data Source](#2-data-source)
# 3. [Data Checks to Perform](#3-data-checks-to-perform)
# 4. [Data Exploration (EDA) with Visualization](#4-data-exploration-eda-with-visualization)
# 5. [Test for Skewness and Normality](#5-test-for-skewness-and-normality)
# 6. [Data Cleaning, Processing and Transformation](#6-data-cleaning-processing-and-transformation)
# 7. [Overall data processing and transformation](#7-overall-data-processing-and-transformation)

# %% [markdown]
# ## 1) Problem Statement <a id="#chapter1"></a>
# This project aims to develop a robust predictive model for company bankruptcy using various financial indicators, which allow stakeholders to make informed decisions in times of crisis.

# %% [markdown]
# ## 2) Data Source <a class="anchor" id="chapter2"></a>
# The dataset contains information about financial indicators leading to bankruptcy prediction of Polish companies.
#
# - Dataset Source: [UC Irvine Machine Learning Repository](https://archive.ics.uci.edu/dataset/365/polish+companies+bankruptcy+data)
# - Contains 495 (rows of) bankrupted companies and 10008 (rows of) operational companies at the end of the 3-year forecasting period.

# %% [markdown]
# ### 2.1 Import required packages

# %%
import requests
import zipfile
import os
from scipy.io import arff

import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ### 2.2 Data Extraction from zip file <a class="anchor" id="section2_1"></a>

# %%
source_url = (
    "https://archive.ics.uci.edu/static/public/365/polish+companies+bankruptcy+data.zip"
)
data_folder_path = "data"
dest_url = "data/downloaded_file.zip"

# %%
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline


class GetZipFile(BaseEstimator, TransformerMixin):

    def fit(self, X):
        return self

    def transform(self, X):
        response = requests.get(source_url)
        with open(dest_url, "wb") as zipfile:
            zipfile.write(response.content)
        return X


class SaveFile(BaseEstimator, TransformerMixin):

    def fit(self, X):
        return self

    @staticmethod
    def extract_arff_from_zip(zip_path, arff_filename, extraction_path="."):
        with zipfile.ZipFile(zip_path, "r") as zip_ref:
            zip_ref.extract(arff_filename, path=data_folder_path)
            return os.path.join(data_folder_path, arff_filename)

    @staticmethod
    def convert_arff_to_csv(arff_path, csv_path):
        data, _ = arff.loadarff(arff_path)
        df = pd.DataFrame(data)
        for col in df.select_dtypes([object]):
            if isinstance(df[col][0], bytes):
                df[col] = df[col].apply(lambda x: x.decode("utf-8"))
        df.to_csv(csv_path, index=False)

    def transform(self, X):
        for i in range(1, 6):
            arff_filename = f"{i}year.arff"
            csv_path0 = f"{i}year.csv"
            extracted_arff_path = self.extract_arff_from_zip(dest_url, arff_filename)

            csv_path = os.path.join(data_folder_path, csv_path0)
            self.convert_arff_to_csv(extracted_arff_path, csv_path)
        return self

# %%
DataExtractionPipeline = Pipeline(
    [("get_zip_file", GetZipFile()), ("save_file", SaveFile())]
)

# DataExtractionPipeline.fit_transform((source_url, dest_url))

# %% [markdown]
# ### 2.3 Import the CSV data as Pandas dataframe
# We chose to use only the 3rd year's dataset - because it has the least number of NULL values.

# %%
df = pd.read_csv("data/3year.csv")
df_origin = df.copy()

# %% [markdown]
# Rename column headings

# %%
columns = [
    "net profit / total assets",
    "total liabilities / total assets",
    "working capital / total assets",
    "current assets / short-term liabilities",
    "[(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365",
    "retained earnings / total assets",
    "EBIT / total assets",
    "book value of equity / total liabilities",
    "sales / total assets",
    "equity / total assets",
    "(gross profit + extraordinary items + financial expenses) / total assets",
    "gross profit / short-term liabilities",
    "(gross profit + depreciation) / sales",
    "(gross profit + interest) / total assets",
    "(total liabilities * 365) / (gross profit + depreciation)",
    "(gross profit + depreciation) / total liabilities",
    "total assets / total liabilities",
    "gross profit / total assets",
    "gross profit / sales",
    "(inventory * 365) / sales",
    "sales (n) / sales (n-1)",
    "profit on operating activities / total assets",
    "net profit / sales",
    "gross profit (in 3 years) / total assets",
    "(equity - share capital) / total assets",
    "(net profit + depreciation) / total liabilities",
    "profit on operating activities / financial expenses",
    "working capital / fixed assets",
    "logarithm of total assets",
    "(total liabilities - cash) / sales",
    "(gross profit + interest) / sales",
    "(current liabilities * 365) / cost of products sold",
    "operating expenses / short-term liabilities",
    "operating expenses / total liabilities",
    "profit on sales / total assets",
    "total sales / total assets",
    "(current assets - inventories) / long-term liabilities",
    "constant capital / total assets",
    "profit on sales / sales",
    "(current assets - inventory - receivables) / short-term liabilities",
    "total liabilities / ((profit on operating activities + depreciation) * (12/365))",
    "profit on operating activities / sales",
    "rotation receivables + inventory turnover in days",
    "(receivables * 365) / sales",
    "net profit / inventory",
    "(current assets - inventory) / short-term liabilities",
    "(inventory * 365) / cost of products sold",
    "EBITDA (profit on operating activities - depreciation) / total assets",
    "EBITDA (profit on operating activities - depreciation) / sales",
    "current assets / total liabilities",
    "short-term liabilities / total assets",
    "(short-term liabilities * 365) / (cost of products sold)",
    "equity / fixed assets",
    "constant capital / fixed assets",
    "working capital",
    "(sales - cost of products sold) / sales",
    "(current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)",
    "total costs /total sales",
    "long-term liabilities / equity",
    "sales / inventory",
    "sales / receivables",
    "(short-term liabilities *365) / sales",
    "sales / short-term liabilities",
    "sales / fixed assets",
    "class",
]

df.columns = columns

# %% [markdown]
# Show Top 5 records

# %%
df.head()
# Out:
#    net profit / total assets  total liabilities / total assets  \
# 0                   0.174190                           0.41299
# 1                   0.146240                           0.46038
# 2                   0.000595                           0.22612
# 3                   0.024526                           0.43236
# 4                   0.188290                           0.41504
#
#    working capital / total assets  current assets / short-term liabilities  \
# 0                         0.14371                                   1.3480
# 1                         0.28230                                   1.6294
# 2                         0.48839                                   3.1599
# 3                         0.27546                                   1.7833
# 4                         0.34231                                   1.9279
#
#    [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  \
# 0                                           -28.9820
# 1                                             2.5952
# 2                                            84.8740
# 3                                           -10.1050
# 4                                           -58.2740
#
#    retained earnings / total assets  EBIT / total assets  \
# 0                           0.60383             0.219460
# 1                           0.00000             0.171850
# 2                           0.19114             0.004572
# 3                           0.56944             0.024526
# 4                           0.00000             0.233580
#
#    book value of equity / total liabilities  sales / total assets  \
# 0                                    1.1225                1.1961
# 1                                    1.1721                1.6018
# 2                                    2.9881                1.0077
# 3                                    1.3057                1.0509
# 4                                    1.4094                1.3393
#
#    equity / total assets  ...  (sales - cost of products sold) / sales  \
# 0                0.46359  ...                                 0.163960
# 1                0.53962  ...                                 0.027516
# 2                0.67566  ...                                 0.007639
# 3                0.56453  ...                                 0.048398
# 4                0.58496  ...                                 0.176480
#
#    (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)  \
# 0                                           0.375740
# 1                                           0.271000
# 2                                           0.000881
# 3                                           0.043445
# 4                                           0.321880
#
#    total costs /total sales  long-term liabilities / equity  \
# 0                   0.83604                        0.000007
# 1                   0.90108                        0.000000
# 2                   0.99236                        0.000000
# 3                   0.95160                        0.142980
# 4                   0.82635                        0.073039
#
#    sales / inventory  sales / receivables  \
# 0             9.7145               6.2813
# 1             5.9882               4.1103
# 2             6.7742               3.7922
# 3             4.2286               5.0528
# 4             2.5912               7.0756
#
#    (short-term liabilities *365) / sales  sales / short-term liabilities  \
# 0                                 84.291                          4.3303
# 1                                102.190                          3.5716
# 2                                 64.846                          5.6287
# 3                                 98.783                          3.6950
# 4                                100.540                          3.6303
#
#    sales / fixed assets  class
# 0                4.0341      0
# 1                5.9500      0
# 2                4.4581      0
# 3                3.4844      0
# 4                4.6375      0
#
# [5 rows x 65 columns]

# %% [markdown]
# ### 2.4 Turn target column to discrete
# Turn target column to discrete, for ease of data checks and data visualisation.

# %%
class AsDiscrete(BaseEstimator, TransformerMixin):

    def fit(self, df):
        return self

    def transform(self, df):
        ncol = len(df.columns) - 1
        feature_space = df.iloc[:, 0:ncol]
        target_column = df.iloc[:, ncol]

        n = len(target_column)
        new_col = [0] * n
        for i in range(n):
            if target_column[i] == "b'0'":
                new_col[i] = 0
            else:
                new_col[i] = 1

        pd_col = pd.DataFrame(new_col, columns=["Target"])
        new_df = pd.concat([feature_space, pd_col], axis=1)

        new_df["Target"] = new_df["Target"].astype("category")

        return new_df

# %%
AsDiscretePipeline = Pipeline(
    [
        ("toDiscrete", AsDiscrete()),
    ]
)

# df = AsDiscretePipeline.fit_transform(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10503 entries, 0 to 10502
# Data columns (total 65 columns):
#  #   Column                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                               --------------  -----
#  0   net profit / total assets                                                                                            10503 non-null  float64
#  1   total liabilities / total assets                                                                                     10503 non-null  float64
#  2   working capital / total assets                                                                                       10503 non-null  float64
#  3   current assets / short-term liabilities                                                                              10485 non-null  float64
#  4   [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  10478 non-null  float64
#  5   retained earnings / total assets                                                                                     10503 non-null  float64
#  6   EBIT / total assets                                                                                                  10503 non-null  float64
#  7   book value of equity / total liabilities                                                                             10489 non-null  float64
#  8   sales / total assets                                                                                                 10500 non-null  float64
#  9   equity / total assets                                                                                                10503 non-null  float64
#  10  (gross profit + extraordinary items + financial expenses) / total assets                                             10503 non-null  float64
#  11  gross profit / short-term liabilities                                                                                10485 non-null  float64
#  12  (gross profit + depreciation) / sales                                                                                10460 non-null  float64
#  13  (gross profit + interest) / total assets                                                                             10503 non-null  float64
#  14  (total liabilities * 365) / (gross profit + depreciation)                                                            10495 non-null  float64
#  15  (gross profit + depreciation) / total liabilities                                                                    10489 non-null  float64
#  16  total assets / total liabilities                                                                                     10489 non-null  float64
#  17  gross profit / total assets                                                                                          10503 non-null  float64
#  18  gross profit / sales                                                                                                 10460 non-null  float64
#  19  (inventory * 365) / sales                                                                                            10460 non-null  float64
#  20  sales (n) / sales (n-1)                                                                                              9696 non-null   float64
#  21  profit on operating activities / total assets                                                                        10503 non-null  float64
#  22  net profit / sales                                                                                                   10460 non-null  float64
#  23  gross profit (in 3 years) / total assets                                                                             10276 non-null  float64
#  24  (equity - share capital) / total assets                                                                              10503 non-null  float64
#  25  (net profit + depreciation) / total liabilities                                                                      10489 non-null  float64
#  26  profit on operating activities / financial expenses                                                                  9788 non-null   float64
#  27  working capital / fixed assets                                                                                       10275 non-null  float64
#  28  logarithm of total assets                                                                                            10503 non-null  float64
#  29  (total liabilities - cash) / sales                                                                                   10460 non-null  float64
#  30  (gross profit + interest) / sales                                                                                    10460 non-null  float64
#  31  (current liabilities * 365) / cost of products sold                                                                  10402 non-null  float64
#  32  operating expenses / short-term liabilities                                                                          10485 non-null  float64
#  33  operating expenses / total liabilities                                                                               10489 non-null  float64
#  34  profit on sales / total assets                                                                                       10503 non-null  float64
#  35  total sales / total assets                                                                                           10503 non-null  float64
#  36  (current assets - inventories) / long-term liabilities                                                               5767 non-null   float64
#  37  constant capital / total assets                                                                                      10503 non-null  float64
#  38  profit on sales / sales                                                                                              10460 non-null  float64
#  39  (current assets - inventory - receivables) / short-term liabilities                                                  10485 non-null  float64
#  40  total liabilities / ((profit on operating activities + depreciation) * (12/365))                                     10301 non-null  float64
#  41  profit on operating activities / sales                                                                               10460 non-null  float64
#  42  rotation receivables + inventory turnover in days                                                                    10460 non-null  float64
#  43  (receivables * 365) / sales                                                                                          10460 non-null  float64
#  44  net profit / inventory                                                                                               9912 non-null   float64
#  45  (current assets - inventory) / short-term liabilities                                                                10485 non-null  float64
#  46  (inventory * 365) / cost of products sold                                                                            10417 non-null  float64
#  47  EBITDA (profit on operating activities - depreciation) / total assets                                                10503 non-null  float64
#  48  EBITDA (profit on operating activities - depreciation) / sales                                                       10460 non-null  float64
#  49  current assets / total liabilities                                                                                   10489 non-null  float64
#  50  short-term liabilities / total assets                                                                                10503 non-null  float64
#  51  (short-term liabilities * 365) / (cost of products sold)                                                             10417 non-null  float64
#  52  equity / fixed assets                                                                                                10275 non-null  float64
#  53  constant capital / fixed assets                                                                                      10275 non-null  float64
#  54  working capital                                                                                                      10503 non-null  float64
#  55  (sales - cost of products sold) / sales                                                                              10460 non-null  float64
#  56  (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)                        10503 non-null  float64
#  57  total costs /total sales                                                                                             10474 non-null  float64
#  58  long-term liabilities / equity                                                                                       10503 non-null  float64
#  59  sales / inventory                                                                                                    9911 non-null   float64
#  60  sales / receivables                                                                                                  10486 non-null  float64
#  61  (short-term liabilities *365) / sales                                                                                10460 non-null  float64
#  62  sales / short-term liabilities                                                                                       10485 non-null  float64
#  63  sales / fixed assets                                                                                                 10275 non-null  float64
#  64  class                                                                                                                10503 non-null  int64
# dtypes: float64(64), int64(1)
# memory usage: 5.2 MB

# %% [markdown]
# Shape of the dataset

# %%
# Overview of the dataset
df.shape
# Out:
# (10503, 65)

# %% [markdown]
# ### 2.5 Dataset information
# -  There are 10503 rows and 65 columns  (64 explanatory variable and one target variable)
# -  Target column:
#     -  bankrupt -> 1
#     -  not-bankrupt -> 0

# %% [markdown]
# There are 64 variables, and 1 target variable:
# - X1 net profit / total assets
# - X2 total liabilities / total assets
# - X3 working capital / total assets
# - X4 current assets / short-term liabilities
# - X5 [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365
# - X6 retained earnings / total assets
# - X7 EBIT / total assets
# - X8 book value of equity / total liabilities
# - X9 sales / total assets
# - X10 equity / total assets
# - X11 (gross profit + extraordinary items + financial expenses) / total assets
# - X12 gross profit / short-term liabilities
# - X13 (gross profit + depreciation) / sales
# - X14 (gross profit + interest) / total assets
# - X15 (total liabilities * 365) / (gross profit + depreciation)
# - X16 (gross profit + depreciation) / total liabilities
# - X17 total assets / total liabilities
# - X18 gross profit / total assets
# - X19 gross profit / sales
# - X20 (inventory * 365) / sales
# - X21 sales (n) / sales (n-1)
# - X22 profit on operating activities / total assets
# - X23 net profit / sales
# - X24 gross profit (in 3 years) / total assets
# - X25 (equity - share capital) / total assets
# - X26 (net profit + depreciation) / total liabilities
# - X27 profit on operating activities / financial expenses
# - X28 working capital / fixed assets
# - X29 logarithm of total assets
# - X30 (total liabilities - cash) / sales
# - X31 (gross profit + interest) / sales
# - X32 (current liabilities * 365) / cost of products sold
# - X33 operating expenses / short-term liabilities
# - X34 operating expenses / total liabilities
# - X35 profit on sales / total assets
# - X36 total sales / total assets
# - X37 (current assets - inventories) / long-term liabilities
# - X38 constant capital / total assets
# - X39 profit on sales / sales
# - X40 (current assets - inventory - receivables) / short-term liabilities
# - X41 total liabilities / ((profit on operating activities + depreciation) * (12/365))
# - X42 profit on operating activities / sales
# - X43 rotation receivables + inventory turnover in days
# - X44 (receivables * 365) / sales
# - X45 net profit / inventory
# - X46 (current assets - inventory) / short-term liabilities
# - X47 (inventory * 365) / cost of products sold
# - X48 EBITDA (profit on operating activities - depreciation) / total assets
# - X49 EBITDA (profit on operating activities - depreciation) / sales
# - X50 current assets / total liabilities
# - X51 short-term liabilities / total assets
# - X52 (short-term liabilities * 365) / (cost of products sold)
# - X53 equity / fixed assets
# - X54 constant capital / fixed assets
# - X55 working capital
# - X56 (sales - cost of products sold) / sales
# - X57 (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)
# - X58 total costs / total sales
# - X59 long-term liabilities / equity
# - X60 sales / inventory
# - X61 sales / receivables
# - X62 (short-term liabilities *365) / sales
# - X63 sales / short-term liabilities
# - X64 sales / fixed assets
# - class (target column)

# %% [markdown]
# ## 3) Data Checks to Perform <a id="chapter3"></a>

# %% [markdown]
# - Check missing values
# - Check duplicates
# - Check data type
# - Check the number of unique values for each column
# - Check statistics of dataset
# - Check various categories present in the different categorical column

# %% [markdown]
# #### 3.1 Check missing values

# %% [markdown]
# Number of missing values in each attribute

# %%
pd.set_option("display.max_rows", None)
df.isna().sum()
# Out:
# net profit / total assets                                                                                                 0
# total liabilities / total assets                                                                                          0
# working capital / total assets                                                                                            0
# current assets / short-term liabilities                                                                                  18
# [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365      25
# retained earnings / total assets                                                                                          0
# EBIT / total assets                                                                                                       0
# book value of equity / total liabilities                                                                                 14
# sales / total assets                                                                                                      3
# equity / total assets                                                                                                     0
# (gross profit + extraordinary items + financial expenses) / total assets                                                  0
# gross profit / short-term liabilities                                                                                    18
# (gross profit + depreciation) / sales                                                                                    43
# (gross profit + interest) / total assets                                                                                  0
# (total liabilities * 365) / (gross profit + depreciation)                                                                 8
# (gross profit + depreciation) / total liabilities                                                                        14
# total assets / total liabilities                                                                                         14
# gross profit / total assets                                                                                               0
# gross profit / sales                                                                                                     43
# (inventory * 365) / sales                                                                                                43
# sales (n) / sales (n-1)                                                                                                 807
# profit on operating activities / total assets                                                                             0
# net profit / sales                                                                                                       43
# gross profit (in 3 years) / total assets                                                                                227
# (equity - share capital) / total assets                                                                                   0
# (net profit + depreciation) / total liabilities                                                                          14
# profit on operating activities / financial expenses                                                                     715
# working capital / fixed assets                                                                                          228
# logarithm of total assets                                                                                                 0
# (total liabilities - cash) / sales                                                                                       43
# (gross profit + interest) / sales                                                                                        43
# (current liabilities * 365) / cost of products sold                                                                     101
# operating expenses / short-term liabilities                                                                              18
# operating expenses / total liabilities                                                                                   14
# profit on sales / total assets                                                                                            0
# total sales / total assets                                                                                                0
# (current assets - inventories) / long-term liabilities                                                                 4736
# constant capital / total assets                                                                                           0
# profit on sales / sales                                                                                                  43
# (current assets - inventory - receivables) / short-term liabilities                                                      18
# total liabilities / ((profit on operating activities + depreciation) * (12/365))                                        202
# profit on operating activities / sales                                                                                   43
# rotation receivables + inventory turnover in days                                                                        43
# (receivables * 365) / sales                                                                                              43
# net profit / inventory                                                                                                  591
# (current assets - inventory) / short-term liabilities                                                                    18
# (inventory * 365) / cost of products sold                                                                                86
# EBITDA (profit on operating activities - depreciation) / total assets                                                     0
# EBITDA (profit on operating activities - depreciation) / sales                                                           43
# current assets / total liabilities                                                                                       14
# short-term liabilities / total assets                                                                                     0
# (short-term liabilities * 365) / (cost of products sold)                                                                 86
# equity / fixed assets                                                                                                   228
# constant capital / fixed assets                                                                                         228
# working capital                                                                                                           0
# (sales - cost of products sold) / sales                                                                                  43
# (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)                             0
# total costs /total sales                                                                                                 29
# long-term liabilities / equity                                                                                            0
# sales / inventory                                                                                                       592
# sales / receivables                                                                                                      17
# (short-term liabilities *365) / sales                                                                                    43
# sales / short-term liabilities                                                                                           18
# sales / fixed assets                                                                                                    228
# class                                                                                                                     0
# dtype: int64

# %% [markdown]
# Number of rows with at least one missing value

# %%
sum(df.apply(lambda row: sum(row.isna().values), axis=1) > 0)
# Out:
# 5618

# %% [markdown]
# Number of columns with at least one missing value

# %%
sum(df.apply(lambda row: sum(row.isna().values), axis=0) > 0)
# Out:
# 44

# %% [markdown]
# #### 3.2 Check duplicates

# %%
df.duplicated().sum()
# Out:
# 87

# %% [markdown]
# There are 87 duplicate rows.

# %% [markdown]
# #### 3.3 Check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10503 entries, 0 to 10502
# Data columns (total 65 columns):
#  #   Column                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                               --------------  -----
#  0   net profit / total assets                                                                                            10503 non-null  float64
#  1   total liabilities / total assets                                                                                     10503 non-null  float64
#  2   working capital / total assets                                                                                       10503 non-null  float64
#  3   current assets / short-term liabilities                                                                              10485 non-null  float64
#  4   [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  10478 non-null  float64
#  5   retained earnings / total assets                                                                                     10503 non-null  float64
#  6   EBIT / total assets                                                                                                  10503 non-null  float64
#  7   book value of equity / total liabilities                                                                             10489 non-null  float64
#  8   sales / total assets                                                                                                 10500 non-null  float64
#  9   equity / total assets                                                                                                10503 non-null  float64
#  10  (gross profit + extraordinary items + financial expenses) / total assets                                             10503 non-null  float64
#  11  gross profit / short-term liabilities                                                                                10485 non-null  float64
#  12  (gross profit + depreciation) / sales                                                                                10460 non-null  float64
#  13  (gross profit + interest) / total assets                                                                             10503 non-null  float64
#  14  (total liabilities * 365) / (gross profit + depreciation)                                                            10495 non-null  float64
#  15  (gross profit + depreciation) / total liabilities                                                                    10489 non-null  float64
#  16  total assets / total liabilities                                                                                     10489 non-null  float64
#  17  gross profit / total assets                                                                                          10503 non-null  float64
#  18  gross profit / sales                                                                                                 10460 non-null  float64
#  19  (inventory * 365) / sales                                                                                            10460 non-null  float64
#  20  sales (n) / sales (n-1)                                                                                              9696 non-null   float64
#  21  profit on operating activities / total assets                                                                        10503 non-null  float64
#  22  net profit / sales                                                                                                   10460 non-null  float64
#  23  gross profit (in 3 years) / total assets                                                                             10276 non-null  float64
#  24  (equity - share capital) / total assets                                                                              10503 non-null  float64
#  25  (net profit + depreciation) / total liabilities                                                                      10489 non-null  float64
#  26  profit on operating activities / financial expenses                                                                  9788 non-null   float64
#  27  working capital / fixed assets                                                                                       10275 non-null  float64
#  28  logarithm of total assets                                                                                            10503 non-null  float64
#  29  (total liabilities - cash) / sales                                                                                   10460 non-null  float64
#  30  (gross profit + interest) / sales                                                                                    10460 non-null  float64
#  31  (current liabilities * 365) / cost of products sold                                                                  10402 non-null  float64
#  32  operating expenses / short-term liabilities                                                                          10485 non-null  float64
#  33  operating expenses / total liabilities                                                                               10489 non-null  float64
#  34  profit on sales / total assets                                                                                       10503 non-null  float64
#  35  total sales / total assets                                                                                           10503 non-null  float64
#  36  (current assets - inventories) / long-term liabilities                                                               5767 non-null   float64
#  37  constant capital / total assets                                                                                      10503 non-null  float64
#  38  profit on sales / sales                                                                                              10460 non-null  float64
#  39  (current assets - inventory - receivables) / short-term liabilities                                                  10485 non-null  float64
#  40  total liabilities / ((profit on operating activities + depreciation) * (12/365))                                     10301 non-null  float64
#  41  profit on operating activities / sales                                                                               10460 non-null  float64
#  42  rotation receivables + inventory turnover in days                                                                    10460 non-null  float64
#  43  (receivables * 365) / sales                                                                                          10460 non-null  float64
#  44  net profit / inventory                                                                                               9912 non-null   float64
#  45  (current assets - inventory) / short-term liabilities                                                                10485 non-null  float64
#  46  (inventory * 365) / cost of products sold                                                                            10417 non-null  float64
#  47  EBITDA (profit on operating activities - depreciation) / total assets                                                10503 non-null  float64
#  48  EBITDA (profit on operating activities - depreciation) / sales                                                       10460 non-null  float64
#  49  current assets / total liabilities                                                                                   10489 non-null  float64
#  50  short-term liabilities / total assets                                                                                10503 non-null  float64
#  51  (short-term liabilities * 365) / (cost of products sold)                                                             10417 non-null  float64
#  52  equity / fixed assets                                                                                                10275 non-null  float64
#  53  constant capital / fixed assets                                                                                      10275 non-null  float64
#  54  working capital                                                                                                      10503 non-null  float64
#  55  (sales - cost of products sold) / sales                                                                              10460 non-null  float64
#  56  (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)                        10503 non-null  float64
#  57  total costs /total sales                                                                                             10474 non-null  float64
#  58  long-term liabilities / equity                                                                                       10503 non-null  float64
#  59  sales / inventory                                                                                                    9911 non-null   float64
#  60  sales / receivables                                                                                                  10486 non-null  float64
#  61  (short-term liabilities *365) / sales                                                                                10460 non-null  float64
#  62  sales / short-term liabilities                                                                                       10485 non-null  float64
#  63  sales / fixed assets                                                                                                 10275 non-null  float64
#  64  class                                                                                                                10503 non-null  int64
# dtypes: float64(64), int64(1)
# memory usage: 5.2 MB

# %% [markdown]
# #### 3.4 Check number of unique values of each column

# %%
df.nunique()
# Out:
# net profit / total assets                                                                                               9948
# total liabilities / total assets                                                                                        9806
# working capital / total assets                                                                                          9947
# current assets / short-term liabilities                                                                                 9425
# [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365    10186
# retained earnings / total assets                                                                                        5864
# EBIT / total assets                                                                                                     9987
# book value of equity / total liabilities                                                                                9939
# sales / total assets                                                                                                    8358
# equity / total assets                                                                                                   9829
# (gross profit + extraordinary items + financial expenses) / total assets                                                9953
# gross profit / short-term liabilities                                                                                  10080
# (gross profit + depreciation) / sales                                                                                   9857
# (gross profit + interest) / total assets                                                                                9987
# (total liabilities * 365) / (gross profit + depreciation)                                                              10028
# (gross profit + depreciation) / total liabilities                                                                      10039
# total assets / total liabilities                                                                                        9209
# gross profit / total assets                                                                                             9987
# gross profit / sales                                                                                                    9999
# (inventory * 365) / sales                                                                                               9348
# sales (n) / sales (n-1)                                                                                                 7962
# profit on operating activities / total assets                                                                           9046
# net profit / sales                                                                                                      9966
# gross profit (in 3 years) / total assets                                                                                9797
# (equity - share capital) / total assets                                                                                 9948
# (net profit + depreciation) / total liabilities                                                                        10021
# profit on operating activities / financial expenses                                                                     8764
# working capital / fixed assets                                                                                          9877
# logarithm of total assets                                                                                               8724
# (total liabilities - cash) / sales                                                                                      9890
# (gross profit + interest) / sales                                                                                      10004
# (current liabilities * 365) / cost of products sold                                                                     9607
# operating expenses / short-term liabilities                                                                             9755
# operating expenses / total liabilities                                                                                  9984
# profit on sales / total assets                                                                                          9959
# total sales / total assets                                                                                              9262
# (current assets - inventories) / long-term liabilities                                                                  5558
# constant capital / total assets                                                                                         9744
# profit on sales / sales                                                                                                 9971
# (current assets - inventory - receivables) / short-term liabilities                                                    10032
# total liabilities / ((profit on operating activities + depreciation) * (12/365))                                        9829
# profit on operating activities / sales                                                                                  9057
# rotation receivables + inventory turnover in days                                                                       9256
# (receivables * 365) / sales                                                                                             9729
# net profit / inventory                                                                                                  9497
# (current assets - inventory) / short-term liabilities                                                                   9754
# (inventory * 365) / cost of products sold                                                                               9362
# EBITDA (profit on operating activities - depreciation) / total assets                                                   9902
# EBITDA (profit on operating activities - depreciation) / sales                                                          9889
# current assets / total liabilities                                                                                      9640
# short-term liabilities / total assets                                                                                   9732
# (short-term liabilities * 365) / (cost of products sold)                                                                9521
# equity / fixed assets                                                                                                   9490
# constant capital / fixed assets                                                                                         9130
# working capital                                                                                                        10156
# (sales - cost of products sold) / sales                                                                                 9909
# (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)                           9925
# total costs /total sales                                                                                                8280
# long-term liabilities / equity                                                                                          5555
# sales / inventory                                                                                                       9255
# sales / receivables                                                                                                     9708
# (short-term liabilities *365) / sales                                                                                   9688
# sales / short-term liabilities                                                                                          9767
# sales / fixed assets                                                                                                    9635
# class                                                                                                                      2
# dtype: int64

# %% [markdown]
# #### 3.5 Check statistics of dataset

# %%
df.describe()
# Out:
#        net profit / total assets  total liabilities / total assets  \
# count               10503.000000                      10503.000000
# mean                    0.052844                          0.619911
# std                     0.647797                          6.427041
# min                   -17.692000                          0.000000
# 25%                     0.000686                          0.253955
# 50%                     0.043034                          0.464140
# 75%                     0.123805                          0.689330
# max                    52.652000                        480.730000
#
#        working capital / total assets  \
# count                    10503.000000
# mean                         0.095490
# std                          6.420056
# min                       -479.730000
# 25%                          0.017461
# 50%                          0.198560
# 75%                          0.419545
# max                         17.708000
#
#        current assets / short-term liabilities  \
# count                             10485.000000
# mean                                  9.980499
# std                                 523.691951
# min                                   0.002080
# 25%                                   1.040100
# 50%                                   1.605600
# 75%                                   2.959500
# max                               53433.000000
#
#        [(cash + short-term securities + receivables - short-term liabilities) / (operating expenses - depreciation)] * 365  \
# count                                       1.047800e+04
# mean                                       -1.347662e+03
# std                                         1.185806e+05
# min                                        -1.190300e+07
# 25%                                        -5.207075e+01
# 50%                                         1.579300e+00
# 75%                                         5.608400e+01
# max                                         6.854400e+05
#
#        retained earnings / total assets  EBIT / total assets  \
# count                      10503.000000         10503.000000
# mean                          -0.121159             0.065624
# std                            6.970625             0.651152
# min                         -508.120000           -17.692000
# 25%                            0.000000             0.002118
# 50%                            0.000000             0.050945
# 75%                            0.072584             0.142275
# max                           45.533000            52.652000
#
#        book value of equity / total liabilities  sales / total assets  \
# count                              10489.000000          10500.000000
# mean                                  19.140113              1.819254
# std                                  717.756745              7.581659
# min                                   -2.081800             -1.215700
# 25%                                    0.431270              1.011275
# 50%                                    1.111000              1.199000
# 75%                                    2.857100              2.059100
# max                                53432.000000            740.440000
#
#        equity / total assets  ...  (sales - cost of products sold) / sales  \
# count           10503.000000  ...                             10460.000000
# mean                0.366093  ...                                -0.530082
# std                 6.428603  ...                                55.978608
# min              -479.730000  ...                             -5691.700000
# 25%                 0.297340  ...                                 0.005137
# 50%                 0.515500  ...                                 0.051765
# 75%                 0.725635  ...                                 0.130010
# max                11.837000  ...                               293.150000
#
#        (current assets - inventory - short-term liabilities) / (sales - gross profit - depreciation)  \
# count                                       10503.000000
# mean                                           -0.014817
# std                                            18.684047
# min                                         -1667.300000
# 25%                                             0.006796
# 50%                                             0.106880
# 75%                                             0.271310
# max                                           552.640000
#
#        total costs /total sales  long-term liabilities / equity  \
# count              10474.000000                    10503.000000
# mean                   3.848794                        1.429319
# std                  190.201224                       77.273270
# min                 -198.690000                     -172.070000
# 25%                    0.875560                        0.000000
# 50%                    0.953060                        0.002976
# 75%                    0.995927                        0.240320
# max                18118.000000                     7617.300000
#
#        sales / inventory  sales / receivables  \
# count       9.911000e+03         10486.000000
# mean        5.713363e+02            13.935361
# std         3.715967e+04            83.704103
# min         0.000000e+00            -6.590300
# 25%         5.533150e+00             4.486075
# 50%         9.952100e+00             6.677300
# 75%         2.093600e+01            10.587500
# max         3.660200e+06          4470.400000
#
#        (short-term liabilities *365) / sales  sales / short-term liabilities  \
# count                           1.046000e+04                    10485.000000
# mean                            1.355370e+02                        9.095149
# std                             2.599116e+04                       31.419096
# min                            -2.336500e+06                       -0.000156
# 25%                             4.073700e+01                        3.062800
# 50%                             7.066400e+01                        5.139200
# 75%                             1.182200e+02                        8.882600
# max                             1.073500e+06                     1974.500000
#
#        sales / fixed assets         class
# count          10275.000000  10503.000000
# mean              35.766800      0.047129
# std              428.298315      0.211926
# min               -0.000102      0.000000
# 25%                2.023350      0.000000
# 50%                4.059300      0.000000
# 75%                9.682750      0.000000
# max            21499.000000      1.000000
#
# [8 rows x 65 columns]

# %% [markdown]
# #### 3.6 Categories in target column

# %%
print("Categories in 'class' variable:    ", end=" ")
print(df["class"].unique())
# Out:
# Categories in 'class' variable:     [0 1]

# %% [markdown]
# Insights
# - All 64 explanatory variables are numerical.
# - 4% of the companies are bankrupt after 3 years.
# - The means are in the range of -1.4 and 35, with most means around 0.
# - Most standard deviations are close, which are less than 7. However, some variables have very large standard deviations of more than 500.
# - The maximum values for ranges from 3.38*10^5 all the way to 53433.
# - There are 3 variables that have at least 100 missing values.
# - There are 87 duplicated rows.

# %% [markdown]
# ## 4) Data Exploration (EDA) with Visualization <a id="chapter4"></a>

# %% [markdown]
# Import required libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from chart_studio import plotly
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode

import cufflinks

cufflinks.go_offline(connected=True)
init_notebook_mode(connected=True)

# make a copy of the datasets for visualization
df_graph = df.copy()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
labels = df["class"].unique().tolist()
values = df["class"].tolist()

# %% [markdown]
# #### 4.1 Pie Chart
# Pie Chart showing the portion of Polish companies that are bankrupt and not bankrupt.

# %%
class_counts = df.groupby("class")["class"].count()
class_counts_df = class_counts.reset_index(name="counts")

label_mapping = {0: "Non-Bankrupt", 1: "Bankrupt"}
class_counts_df["class"] = class_counts_df["class"].map(label_mapping)

custom_colors = ["#636efa", "#eb543c"]

class_counts_df
# Out:
#           class  counts
# 0  Non-Bankrupt   10008
# 1      Bankrupt     495

# %%
# using iplot from cufflinks

class_counts_df.iplot(
    kind="pie",
    labels="class",
    values="counts",
    title="Percentage of Polish Bankrupt and Not Bankrupt Companies",
    colors=custom_colors,
    textinfo="label+percent",
)
# Out:
# <div>                            <div id="fb9f8331-b45b-4ae1-832a-39dbcf18aeb4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("fb9f8331-b45b-4ae1-832a-39dbcf18aeb4")) {                    Plotly.newPlot(                        "fb9f8331-b45b-4ae1-832a-39dbcf18aeb4",                        [{"labels":["Non-Bankrupt","Bankrupt"],"marker":{"colors":["rgba(99, 110, 250, 1.0)","rgba(235, 84, 60, 1.0)"]},"name":"","textinfo":"label+percent","values":[10008,495],"type":"pie"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","titlefont":{"color":"#4D5663"},"title":"Percentage of Polish Bankrupt and Not Bankrupt Companies"},                        {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('fb9f8331-b45b-4ae1-832a-39dbcf18aeb4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                });            </script>        </div>

# %%
# using go from plotly

fig = go.Figure(
    data=[
        go.Pie(
            labels=class_counts_df["class"],
            values=class_counts_df["counts"],
            marker=dict(colors=custom_colors),
            textinfo="label+percent",
            hoverinfo="label+percent+value",
            hole=0.4,  # for donut
        )
    ]
)

fig.update_layout(
    title_text="Percentage of Polish Bankrupt and Not Bankrupt Companies",
    showlegend=True,
)

fig.show()
# Out:
# <div>                            <div id="318d7048-7361-49fe-b299-376951f91908" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("318d7048-7361-49fe-b299-376951f91908")) {                    Plotly.newPlot(                        "318d7048-7361-49fe-b299-376951f91908",                        [{"hole":0.4,"hoverinfo":"label+percent+value","labels":["Non-Bankrupt","Bankrupt"],"marker":{"colors":["#636efa","#eb543c"]},"textinfo":"label+percent","values":[10008,495],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"t ...
#
# var gd = document.getElementById('318d7048-7361-49fe-b299-376951f91908');
# var x = new MutationObserver(function (mutations, observer)

# %% [markdown]
# #### 4.2 Tree Map
# Tree map to show proportion of bankrupt companies in our dataset.

# %%
fig = px.treemap(
    class_counts_df,
    path=["class"],
    values="counts",
    color="class",
    color_discrete_sequence=custom_colors,
    hover_name=class_counts_df["class"],
)

fig.update_layout(
    title="Percentage of Polish Bankrupt and Non-Bankrupt Companies",
    title_x=0.5,
    font=dict(family="Arial", size=15, color="black"),
    margin=dict(t=50, l=10, r=10, b=10),
    plot_bgcolor="rgba(0,0,0,0)",
)

fig.update_traces(
    hovertemplate="<br>%{label}<br>count : %{value}<br>percent : %{percentRoot:.2%}"
)

fig.show()
# Out:
# <div>                            <div id="1046ce39-cee0-4435-bc32-a22578b588eb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1046ce39-cee0-4435-bc32-a22578b588eb")) {                    Plotly.newPlot(                        "1046ce39-cee0-4435-bc32-a22578b588eb",                        [{"branchvalues":"total","customdata":[["Non-Bankrupt"],["Bankrupt"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"\u003cbr\u003e%{label}\u003cbr\u003ecount : %{value}\u003cbr\u003epercent : %{percentRoot:.2%}","hovertext":["Non-Bankrupt","Bankrupt"],"ids":["Non-Bankrupt","Bankrupt"],"labels":["Non-Bankrupt","Bankrupt"],"marker":{"colors":["#636efa","#eb543c"]},"name":"","parents":["",""],"values":[10008,495],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"co ...

# %% [markdown]
# The pie chart, donut chart, and tree map shows the class imbalance in our dataset.

# %% [markdown]
# #### 4.3 Missingness Map
# We first plot a missingness map to see the sparsity of our dataset.

# %%
# Create a missingness matrix
missing_values = df_graph.isnull()

# Plot the missingness map
plt.figure(figsize=(10, 6))
sns.heatmap(missing_values, cmap="viridis", cbar=False)
plt.title("Missingness Map")
plt.xlabel("Variables")
plt.ylabel("Observations")
plt.yticks([])
plt.show()

# %% [markdown]
# We can see that:
# -  `X37 (current assets - inventories) / long-term liabilities` are almost filled with missing values with variation in occurrence.
# -  There are 6 variables with moderate number of missing values.
# -  There are 37 variables with sparsely located missing values.
# -  In total, there are 44 variables that have at least one missing values, as verified in the data checks section.

# %% [markdown]
# #### 4.4 Histogram

# %%
# Here we illustrate the histogram distribution for the first 4 features
df_graph = df.copy()
features = df_graph.columns[:4]
fig, axes = plt.subplots(2, 2, figsize=(10, 6))

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, feature in enumerate(features):
    sns.histplot(df_graph[feature], bins=10, ax=axes[i], color="#636efa", alpha=0.7)
    axes[i].set_ylabel("Frequency")
    axes[i].set_title(f"Histogram of {feature}")
    axes[i].grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# We see that there is one or two bars in each histogram. This means that most data are concentrated within a small range, and that there are outliers.
# View individual histogram below to see the distribution more clearly.
#
# Change the index (0-64) at `explanatory_variable_index`.

# %%
explanatory_variable_index = 45

df.iloc[:, explanatory_variable_index].iplot(
    kind="hist",
    bins=30,
    title=f"Histogram for {df.columns[explanatory_variable_index]}",
    yTitle="Frequency",
    xTitle=df.columns[explanatory_variable_index],
    linecolor="black",
)
# Out:
# <div>                            <div id="8a3cdd02-b0c4-4683-b0c0-96a22ff94955" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("8a3cdd02-b0c4-4683-b0c0-96a22ff94955")) {                    Plotly.newPlot(                        "8a3cdd02-b0c4-4683-b0c0-96a22ff94955",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#000000","width":1.3}},"name":"(current assets - inventory) \u002f short-term liabilities","nbinsx":30,"opacity":0.8,"orientation":"v","x":[0.90221,1.033,2.329,0.90954,0.52685,1.2019,109.72,0.98398,0.78182,0.6804,0.60813,1.6532,2.7133,1.822,0.45101,0.54832,2.9922,1.6362,1.7812,1.6305,1.7181,2.0072,0.85472,1.9544,1.5097,4.2798,0.59938,1.3073,1.1273,1.3712,2.7199,2.1761,5.2739,1.0906,0.4929,0.35589,0.66701,1.0074,0.71543,1.3923,1.7197,7.4183,0.5734,0.65454,1.1823,1.5322,0.89227,0.4198,0.90243,1.9131,2.9628,6.7818,2.7683,2.876,0.17237,0.7716,0.37559,1.0118,0.67747,0.34035,0.76463,2.4949,0.29604,1.5062,1.1095,11.691,6.3752,0.55307,8.8368,2.3465,5.3002,1.6119,1.8279,2.1307,1.0822,3.1085,0.35526,0.26101,0.1345,0.33609,0.4792,4.1895,0.98243,3.2289,1.08,0.9469,0.50902,0.73012,2.1844,1.0023,2.7961,2.4537,0.93417,0.81572,0.77704,0.70071,0.10013,0.91534,2.0263,2.2524,1.963,1.204,4.6132,0.79509,1.007,0.81846,0.49092,2.4203,1.1817,1.0985,1.9284,0.13387,5.6026,0.81221,1.0612,0.18293,0.76742,0.4487,1.0479,2.4368,7.2376,2.4442,0.58286,1.4345,0.37017,1.1656,0.98344,0.55147,2.7354,0.51251,0.52881,32.191,3.5542,1.3816,2.6597,2.3366,0.51652,0.46289,1.3049,0.38174,1.1383,0.57039,1.0925,1.8193,2.2283,0.56719,4.1139,1.5841,1.5841,1.3986,0.38475,0.76831,1.675,0.82274,4.951,10.904,34.902,9.2382,1.1946,2.5705,1.701,0.95279,0.81777,1.8785,0.47159,1.0325,6.6839,1.1182,2.6075,0.54497,22.362,1.6511,2.5703,1.0841,1.3623,0.68983,1.0854,3.9983,0.95402,2.1462,0.57883,0.54527,1.0105,1.601,1.0111,0.64082,14.255,2.0802,2.2301,0.23456,0.74251,0.70664,1.4762,0.4262,0.53576,0.17322,6.8174,0.85091,3.0693,-0.040817,11.203,0.49765,2.0571,0.27285,3.8037,18.193,0.65518,0.54418,1.1585,1.0363,2.2429,0.56564,1.557,2.7003,0.70482,3.6159,0.77224,0.13397,0.79956,0.36558,1.075,1.4781,2.9157,0.55579,1.1365,0.84383,0.75145,2.419,1.0403,1.4203,0.83169,1.0292,0.25892,0.64838,0.83962,2.4561,0.069647,3.0706,0.67195,1.1702,10.364,0.72991,1.4449,3.2264,0.8075,2.5456,1.555,3.4427,1.8518,2.8055,2.7552,2.5291,2.9239,9.1191,0.50557,1.7891,1.6381,1.1148,1.1746,1.2045,2.2923,4.8676,175.2,2.6635,1.3691,1.7117,3.4582,2.9025,2.9155,1.7129,5.0737,6.3763,8.9921,4.7071,2.7302,3.9193,12.397,4.5095,1.3576,3.8085,1.1527,0.88893,1.0867,2.0887,1.2189,5.1371,1.1701,0.3553,1.0851,0.7197,0.37315,1.1107,1.3343,0.76903,0.95897,1.9434,0.58987,1.7835,0.34654,1.2995,1.1318,1.1944,0.097891,2.1582,1.8628,2.1257,2.8377,2.2937,3.4256,1.8606,1.5389,0.54108,0.64991,0.79479,0.79479,1.8736,0.50653,1.6491,1.3231,2.544,1.5446,0.44969,2.3275,0.5945,1.3199,0.28998,0.97815,5.2731,3.7779,0.7169,0.71914,3.6016,3.1734,3.3096,0.96637,1.5075,0.24298,4.3576,0.48387,4.3292,1.4387,0.52771,0.93628,1.4165,2.964,2.6825,1.8899,0.4589,1.4067,2.7305,0.3183,5.706,1.1952,0.6445,0.82932,1.8924,1.6656,0.48772,7.9407,2.3945,0.87,0.66665,0.37878,4.4203,0.75716,1.3769,1.9924,1.3593,10.1,13.859,5.9284,0.89536,2.8684,0.81363,2.4928,1.3495,55.768,2.1039,1.2963,1.0553,0.44968,0.19729,584.33,1.6632,3.4537,1.1614,0.49553,1.2971,0.5664,0.48616,0.34879,1.1733,1.6921,1.3826,1.7587,4.8357,56.724,0.52526,0.53403,12.128,2.0823,4.1067,0.76987,8.6961,0.27449,0.85705,2.0338,1.399,0.71898,0.60165,2.9417,2.6008,0.82161,0.34363,48.938,0.70533,4.3375,1.1983,0.71001,1.3478,2.04,4.4704,0.95806,0.22754,0.86796,12.92,2.728,2.3359,0.7985,216.89,1.118,7.8073,0.57661,0.87911,0.21762,8.012,1.0024,2.5493,0.7874,40.974,0.38094,3.3124,0.8512,2.0436,1.8382,0.22721,1.1443,0.26472,3.5189,0.54113,1.6442,0.61709,0.55542,0.66418,0.14774,0.21779,0.3501,1.7915,0.35729,0.40341,0.80727,2.196,2.2654,1.8076,1.8029,3.1124,3.1409,9.9294,0.24438,5.1718,7.3287,1.1042,1.2835,1.0304,1.2509,1.3002,0.82812,0.594 ...

# %% [markdown]
# #### 4.5 Density Plot

# %%
features = df_graph.columns[:4]
fig, axes = plt.subplots(2, 2, figsize=(10, 6))

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, feature in enumerate(features):
    sns.kdeplot(df_graph[feature], ax=axes[i], color="#636efa", linewidth=2)
    axes[i].set_ylabel("Density")
    axes[i].set_title(f"Density Plot of {feature}")
    axes[i].grid(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4.6 Boxplot
# To see data distribution and outliers for all explanatory variables.

# %%
plt.figure(figsize=(15, 40))
i = 1

for column in df_graph.columns[:-1]:
    ax = plt.subplot(22, 3, i)  # Adjust layout as needed
    i += 1
    sns.boxplot(
        data=df_graph[column],
        color="skyblue",
        ax=ax,
        boxprops=dict(edgecolor="lightgrey"),
    )
    ax.set_title(f"Box Plot of {column}", fontsize=8)
    ax.set_ylabel("Value")

plt.tight_layout()
plt.show()

# %% [markdown]
# To see boxplot for individual explanatory variable. Change the index (0-64) at `explanatory_variable_index`.
# Hover over each outlier to see its value.

# %%
explanatory_variable_index = 10

df.iloc[:, explanatory_variable_index].iplot(
    kind="box",
    boxpoints="outliers",
    layout=dict(
        height=400,
        yaxis=dict(title="value"),
        title=f"Boxplot for {df.columns[explanatory_variable_index]}",
        margin=dict(b=140),
    ),
)
# Out:
# <div>                            <div id="ecef3982-dabc-49bf-b1e8-455bd7e8f047" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ecef3982-dabc-49bf-b1e8-455bd7e8f047")) {                    Plotly.newPlot(                        "ecef3982-dabc-49bf-b1e8-455bd7e8f047",                        [{"boxpoints":"outliers","line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"(gross profit + extraordinary items + financial expenses) \u002f total assets","orientation":"v","y":[0.21946,0.17579,0.0045718,0.024526,0.23881,0.20766,0.1435,0.055717,0.33061,-0.11986,-0.12478,0.10728,0.098854,0.094949,-0.18972,0.0138,0.34154,-0.089098,0.21397,0.13782,-0.13221,0.04521,0.029986,0.095602,0.21893,0.35334,-0.026971,0.19444,0.039223,0.072379,0.11652,0.33593,0.23145,0.011205,-0.01251,0.044384,0.0,0.18976,0.017461,0.015213,0.36987,0.22377,-0.014792,0.23794,0.18077,0.14407,0.11189,-0.027417,-0.085078,0.26332,0.13815,0.87642,0.14685,0.15042,0.19712,0.1737,0.035916,0.097222,0.05624,0.057397,0.044852,0.19401,-0.10115,0.032353,0.19131,0.14987,0.010436,0.035691,0.090058,1.9006,0.026635,0.03274,0.10108,0.057686,-0.19111,0.020308,0.072238,-0.11564,-0.24348,0.11578,0.0014362,0.14687,0.052224,0.013688,-0.027863,-0.023229,0.13604,0.002887,0.25468,0.073597,0.096424,0.061969,0.028085,0.0068216,0.032197,0.011289,0.067003,0.089625,0.054657,0.16954,0.056117,-0.23077,0.052055,-0.29451,0.006313,0.017209,0.021576,0.074661,0.17943,0.078354,0.037917,0.11686,0.41545,0.16142,0.023278,-0.14566,0.17166,-0.021852,0.00167,-0.17747,0.24569,-0.056009,0.034019,0.41828,0.25085,0.98063,-0.055837,0.11245,-0.0082923,0.031113,0.063578,0.011918,0.2311,0.029215,0.23295,0.33401,0.016181,0.055415,0.050682,-0.033935,0.037718,0.038055,0.36202,-0.0017718,0.24736,0.40499,0.023907,0.21283,0.21283,0.010455,-0.10755,0.038748,0.013903,0.11931,0.2393,-0.18174,-0.45969,0.096291,0.13904,-0.12321,0.26706,0.022155,0.15391,0.070571,0.13946,0.19055,0.38295,0.080371,0.52033,-0.076147,0.24289,0.037526,0.03157,0.026358,0.1524,0.13035,0.059275,0.13571,-0.16622,0.95516,0.045178,0.089651,0.11964,0.048722,0.21431,-0.014273,0.21776,-0.033045,0.22667,-0.10198,0.023365,0.077935,0.019248,0.053438,0.024673,4.9762,0.062392,0.16821,-0.11585,0.11261,0.041496,0.26315,0.1131,0.16566,0.15385,0.16386,0.022617,-0.11033,0.076292,0.069109,0.37242,-0.038781,-0.06259,0.098811,0.022254,0.15549,0.25548,-0.39087,0.0013516,0.067489,-0.10753,0.18096,0.42797,0.11436,-0.014563,-0.024907,0.066674,0.28353,0.018903,0.059097,0.11947,0.062881,0.0054052,-0.21927,0.0005749,0.13032,-0.048695,0.051,-0.048797,0.068192,0.33285,0.27659,0.13809,0.22433,-0.03647,0.27043,-0.14548,0.26239,0.36392,0.2706,0.0066621,0.19909,0.18428,0.3629,0.06571,0.0065891,0.049467,-0.20617,0.029647,0.081801,0.038765,0.32638,0.00047606,0.17619,0.14918,0.36018,0.13297,0.21401,0.26842,0.0014875,0.21026,0.108,0.85276,0.21417,0.22458,0.14023,0.2639,0.041651,0.093928,0.22864,0.019858,0.034306,0.038765,0.052292,0.096132,0.15536,-0.028814,0.17213,0.094039,0.24197,-0.040757,0.03254,0.087324,0.1701,0.28109,-0.042074,-0.26002,0.26413,0.084271,0.26042,0.1453,0.029642,0.096452,0.20975,0.14765,0.45821,0.064879,0.026892,0.0013782,0.047949,0.055501,-0.28942,0.081977,0.19283,0.20827,0.1689,-0.35158,0.025184,-0.071053,-0.032721,0.15335,-0.062928,0.073514,-0.082152,0.30376,0.59382,-0.014427,0.24314,-0.24589,0.028301,0.10875,0.788,0.24372,0.020315,0.32749,0.06909,-0.14314,0.076694,0.092061,0.0060204,0.078671,-0.17282,0.17763,-0.50927,0.33559,0.065366,0.17269,0.065286,0.2343,0.24515,-0.11936,0.069,0.12337,0.017071,0.15973,0.13698,0.18856,0.079946,0.34164,0.24096,-0.0020373,0.57074,-0.11418,0.25024,0.17305,0.0057556,0.11788,0.45456,0.020876,0.030062,0.50927,-0.10551,0.24503,0.011119,0.26497,0.14555,0.15407,0.24847,0.046196,0.019732,-0.53794,-0.2236,0.15541,0.025575,0.06988,0.10232,0.0066759,0.33547,-0.2032,0.061365,0.16622,0.083481,0.082765,0.16269,0.12513,0.21269,0.041762,0.41121,-0.0013956,0.070161,0.064047,0.1185,0.075648,0.36003,-0.12121,0.046417,0.66364,0.31281,0.05 ...

# %% [markdown]
# From the histogram and boxplots, we can see that we have many outliers for each explanatory variable in our dataset.

# %% [markdown]
# ## 5) Test for Skewness and Normality

# %% [markdown]
# ### 5.1 Test for Skewness
#
# Interpreting Skewness:
# - Skewness < -1 or Skewness > 1: Highly skewed.
# - -1 < Skewness < -0.5 or 0.5 < Skewness < 1: Moderately skewed.
# - -0.5 < Skewness < 0.5: Approximately symmetric.

# %%
skewness = df.skew()
# print("Skewness of each feature:\n", skewness)

skewed_features = skewness[abs(skewness) > 0.5]
num_skewed_features = len(skewed_features)
print(f"Number of skewed features: {num_skewed_features}")
print(f"{num_skewed_features} out of {len(df.columns)} features are skewed.")
# Out:
# Number of skewed features: 64
# 64 out of 65 features are skewed.

# %% [markdown]
# From above, we see that almost all of the features are skewed.

# %% [markdown]
# ### 5.2 Test for normality
#
# There are 4 statistical tests that we can use to test for normality in our data. These are:
# 1. **Shapiro-Wilk Test**: Suitable for small to medium-sized datasets.
# 2. **Kolmogorov-Smirnov Test**: Suitable for larger datasets.
# 3. **Anderson-Darling Test**: An extension of the Kolmogorov-Smirnov test, often considered more powerful.
# 4. **Jarque-Bera Test**: Suitable for larger datasets, based on skewness and kurtosis.
#
# Since our dataset has 10,501 samples and 62 out of 64 features are skewed, we will use Anderson-Darling test and the Kolmogorov-Smirnov test, as they are more suitable for larger sample sizes and can provide a better assessment of normality.
#
# Using both tests could give us a comprehensive view of normality across the features.

# %% [markdown]
# #### 5.2.1 Shapiro Wilk Test

# %%
from scipy.stats import shapiro, kstest, anderson, normaltest

shapiro_results = df.apply(lambda x: shapiro(x)[1])

# Check how many features are normally distributed
normal_features = shapiro_results[shapiro_results > 0.05]
non_normal_features = shapiro_results[shapiro_results <= 0.05]

print(f"Number of normally distributed features: {len(normal_features)}")
print(f"Number of non-normally distributed features: {len(non_normal_features)}")
# Out:
# Number of normally distributed features: 0
# Number of non-normally distributed features: 21

# %% [markdown]
# #### 5.2.2 Kolmogorov-Smirnov test

# %%
from scipy.stats import kstest

ks_results = df.apply(lambda x: kstest(x, "norm")[1])

# Check how many features are normally distributed
normal_features = ks_results[ks_results > 0.05]
non_normal_features = ks_results[ks_results <= 0.05]

print(f"Number of normally distributed features: {len(normal_features)}")
print(f"Number of non-normally distributed features: {len(non_normal_features)}")
# Out:
# Number of normally distributed features: 0
# Number of non-normally distributed features: 21

# %% [markdown]
# #### 5.2.3 Anderson-Darling Test

# %%
significance_level = 5
normally_distributed_count = 0

for column in df.columns[:-1]:
    result = anderson(df[column], dist="norm")
    critical_value = result.critical_values[
        np.where(result.significance_level == significance_level)[0][0]
    ]

    # Count the feature as normally distributed if the test statistic is less than the critical value
    if result.statistic < critical_value:
        normally_distributed_count += 1

print(f"Number of normally distributed features: {normally_distributed_count}")
# Out:
# Number of normally distributed features: 0

# %% [markdown]
# From the above 3 normality test, we can conclude that all features in the dataframe df is not normally distributed.

# %% [markdown]
# ## 6) Data Cleaning, Processing and Transformation <a class="anchor" id="7-overall-data-processing-and-transformation"></a>
# Performed data imputation, removal of null values and normalisation

# %% [markdown]
# For more accurate visualisation and outlier detection later on.

# %%
from data_cleaning import get_Xy, med_impute, normalise, map_class_labels


# Performed data imputation, removal of null values and normalisation
def df_cleaning1(df):
    X, y = get_Xy(df)
    X_imputed, y = med_impute(
        X, y
    )  # removed the columns with more than 40% null values
    X_scaled_df = normalise(X_imputed)
    y_df = pd.DataFrame(y)
    y_df.rename(columns={0: "class"}, inplace=True)
    df_concat = pd.concat([X_scaled_df, y_df], axis=1)
    result_df = map_class_labels(df_concat)  # .fillna(df.median())
    return result_df


# new
def df_cleaning1(df):
    X, y = get_Xy(df)
    X_imputed, y = med_impute(X, y)
    X_scaled_df = normalise(X_imputed)
    y_df = pd.DataFrame(y)

    X_scaled_df.reset_index(drop=True, inplace=True)
    y_df.reset_index(drop=True, inplace=True)

    df_concat = pd.concat([X_scaled_df, y_df], axis=1)
    df_concat["class"] = df_concat["class"].astype(int)
    result_df = map_class_labels(df_concat)
    return result_df


df = df_cleaning1(df)
df.shape
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 from data_cleaning import get_Xy, med_impute, normalise, map_class_labels
#       4 # Performed data imputation, removal of null values and normalisation
#       5 def df_cleaning1(df):
#
# File ~/Downloads/Bankruptcy-Prediction/notebook/data_cleaning.py:4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from imblearn.over_sampling import SMOTE
#       5 from scipy.stats import boxcox
#       6 from sklearn.base import BaseEstimator, TransformerMixin
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/imblearn/__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/imblearn/combine/__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/imblearn/combine/_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~/miniconda3/envs/dev/lib/python3.10/site-packages/imblearn/base.py:20
#      17     from sklearn.base import _OneToOneFeatureMixin as OneToOneFeatureMixin
#      19 from sklearn.preprocessing import label_binarize
# ---> 20 from sklearn.utils import parse_version
#      21 from sklearn.utils.multiclass import check_classification_targets
#      23 from .utils import check_sampling_strategy, check_target_type
#
# ImportError: cannot import name 'parse_version' from 'sklearn.utils' (/Users/carlychinsekyi/miniconda3/envs/dev/lib/python3.10/site-packages/sklearn/utils/__init__.py)

# %% [markdown]
# One feature was dropped due to high number of missing values.
# After data cleaning and processing above, let's check the features' skewness and normality below.

# %% [markdown]
# ### 6.1 Check skewness after df_cleaning1

# %%
X, y = get_Xy(df)
skewness = X.skew()
skewed_features = skewness[abs(skewness) > 0.5]
num_skewed_features = len(skewed_features)

print(f"Number of skewed features: {num_skewed_features}")
print(f"{num_skewed_features} out of {len(df.columns)} features are skewed.")

# %% [markdown]
# Above, we see that most of the features are still skewed. Let's attempt to solve them below.

# %% [markdown]
# ### 6.2 Dealing with skewed data with data transformation
# Here, we experimented with 4 ways to deal with skewed data through **data transformation**.
# - **Log Transformation**
#   - Formula:
#     $$\log(x + 1)\$$
#   - Effective for right-skewed data.
#   - Limitations: Not suitable for negative values or zeros.
#
# - **Square Root Transformation**
#   - Formula:
#     $$\sqrt{x}\$$
#   - Suitable for moderately skewed data.
#   - Limitations: Cannot handle negative values or zeros.
#
# - **Cube Root Transformation**
#   - Formula:
#     $$\sqrt[3]{x}\$$
#   - Can be applied to both positive and negative values.
#   - Suitable for moderate skewness.
#
# - **Box-Cox Transformation**
#   - Formula: (requires positive values)
#     $$\frac{x^{\lambda} - 1}{\lambda} \$$
#   - Finds the optimal transformation parameter.
#   - Limitations: Only applicable to positive values.

# %%
from data_cleaning import (
    log_transform,
    sqrt_transform,
    cube_root_transform,
    boxcox_transform,
    check_skewness,
)

# Apply transformations
df_log_transformed = log_transform(df)
df_sqrt_transformed = sqrt_transform(df)
df_cube_root_transformed = cube_root_transform(df)
df_boxcox_transformed = boxcox_transform(df)

print(f"Skewed features after log transformation: {check_skewness(df_log_transformed)}")
print(
    f"Skewed features after square root transformation: {check_skewness(df_sqrt_transformed)}"
)
print(
    f"Skewed features after cube root transformation: {check_skewness(df_cube_root_transformed)}"
)
print(
    f"Skewed features after Box-Cox transformation: {check_skewness(df_boxcox_transformed)}"
)

# %% [markdown]
# The data transformation methods above are insufficient to solve the skewness in the dataset. This might be due to the extreme skewness in our dataset. However, the cube root transformation successfully reduces the skewness of one feature. Therefore, we will use the cube root transformation for our data.
#
# Next, we will explore the presence of outliers in the dataset to further address skewness and improve data quality.

# %%
df = df_cube_root_transformed = cube_root_transform(df)

# %% [markdown]
# ### 6.3 Check Normality after df_cleaning1

# %%
# Shapiro Wilk Test
X, y = get_Xy(df)
shapiro_results = X[:-1].apply(lambda x: shapiro(x)[1])

normal_features = shapiro_results[shapiro_results > 0.05]
non_normal_features = shapiro_results[shapiro_results <= 0.05]

print(f"Number of normally distributed features: {len(normal_features)}")
print(f"Number of non-normally distributed features: {len(non_normal_features)}")

# %%
# Kolmogorov-Smirnov test
X, y = get_Xy(df)
ks_results = X.apply(lambda x: kstest(x, "norm")[1])

# Check how many features are normally distributed
normal_features = ks_results[ks_results > 0.05]
non_normal_features = ks_results[ks_results <= 0.05]

print(f"Number of normally distributed features: {len(normal_features)}")
print(f"Number of non-normally distributed features: {len(non_normal_features)}")

# %% [markdown]
# After data transformation, all features in our dataframe is stil not normally distributed.

# %% [markdown]
# ### 6.4 Dealing with Outliers<a id="section2_2_2"></a>

# %% [markdown]
# There are several methods to deal with outliers:
# 1. Percentile Method - useful for identifying outliers in symmetrical and normal distributions
# 2. IQR Method
# 3. Z-score Method
# 4. Data transformation - ie log transformation to reduce skewness in data
# 5. Impute outliers

# %% [markdown]
# #### Method 1: **Percentile Method**
# Useful for identifying outliers in symmetrical and normal distributions. However, as seen in the histogram and density plots above, the dataset is not symmetrical nor normally distributed. Hence, we shall omit this method for dealing with outliers.

# %% [markdown]
# #### Method 2: **IQR Method**

# %%
import numpy as np


def remove_outliers(df, column, iqr_factor=1.5):
    if df[column].empty:
        return df

    column_values = df[column].values
    Q1 = np.percentile(column_values, 0.25)
    Q3 = np.percentile(column_values, 0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - iqr_factor * IQR
    upper_bound = Q3 + iqr_factor * IQR

    df = df[(df[column] > lower_bound) & (df[column] < upper_bound)]

    return df


df_cleaned = df.copy()
for column in df.columns:
    df_cleaned = remove_outliers(df_cleaned, column)

df_cleaned.shape

# %% [markdown]
# Using 1.5 times IQR method to remove outliers causes all rows to be removed in the dataset because the values in each column is very skewed. Hence, we shall not use this method to deal with outliers.

# %% [markdown]
# #### Method 3: **Z-score Method**
# We shall also omit this method for dealing with outliers since our data for each feature is neither symmetrical nor normally distributed.

# %% [markdown]
# #### Method 4: Using Median Absolute Deviation (MAD)
#
# The Median Absolute Deviation (MAD) is a robust statistic used to measure the variability of a dataset. It is particularly useful for identifying outliers in skewed data. The MAD is calculated as follows:
#
# 1. Compute the median of the data.
# 2. Subtract the median from each data point to obtain the absolute deviations.
# 3. Calculate the median of these absolute deviations.

# %%
from data_cleaning import remove_outliers_mad, apply_mad_removal

df_mad_cleaned = apply_mad_removal(df)

print(f"df_mad_cleaned shape: {df_mad_cleaned.shape}")

# %% [markdown]
# Using the Median Absolute Deviation (MAD) to remove outliers resulted in a significant reduction of the dataset size. Initially, the dataset had around 10,000 rows and 64 columns. After applying the MAD method for outlier detection, the cleaned dataset was reduced to only 103 rows.
#
# This drastic reduction indicates that the MAD method may be too stringent for this particular dataset, leading to the removal of a substantial amount of data. As a result, the remaining dataset is too small for effective model training. This suggests that while MAD is a robust method for outlier detection, it might not be suitable for this dataset, especially when preserving a larger portion of the data is crucial for building reliable models.

# %% [markdown]
# #### Method 5: **Data transformation**

# %%
# Apply transformations
transformations = {
    "log": log_transform,
    "sqrt": sqrt_transform,
    "cube_root": cube_root_transform,
    "boxcox": boxcox_transform,
}

# Apply each transformation and MAD outlier removal
for name, transform_func in transformations.items():
    df_transformed = transform_func(df)
    df_cleaned = apply_mad_removal(df_transformed)
    print(f"df_{name}_transformed shape: {df_transformed.shape}")
    print(f"df_{name}_cleaned shape: {df_cleaned.shape}")

# Apply MAD method directly on original data
df_mad_cleaned = apply_mad_removal(df)

print(f"df_mad_cleaned shape: {df_mad_cleaned.shape}")

# %% [markdown]
# After applying data transformation, the majority of rows from the dataset is removed. As a result the remaining dataset is once again too small for effective model training. Hence, data transformation is not suitable for our dataset.

# %% [markdown]
# #### Method 6: **Impute outliers**
# Since our data is highly skewed, it is not reliable to use the mean or median for outlier imputation. Thus, we shall omit this method for dealing with outliers.

# %% [markdown]
# ### 6.5 Overall conclusion to dealing with outliers
#
# TLDR: We will not remove the outliers from the dataset.

# %%
from data_cleaning import count_and_percentage_outliers

outliers_table = count_and_percentage_outliers(df)
top3_max_percentages = outliers_table.nlargest(3, "Percentage of Outliers")

print("Top 3 maximum percentages of outliers:")
print(top3_max_percentages[["Column", "Percentage of Outliers"]])

outliers_table.head()

# %% [markdown]
# Here, the top 3 columns exhibit significant percentages of outliers, likely influenced by the diverse scales of companies represented in the dataset, leading to varying earnings and profit margins. Despite these outliers, these features are important to understanding the dataset's diversity and should not be removed as they reflect legitimate variations rather than errors.

# %% [markdown]
# ---

# %% [markdown]
# ## 7) Overall data processing and transformation <a class="anchor" id="chapter7"></a>

# %% [markdown]
# Import dataset into dataframe

# %%
df = pd.read_csv("data/3year.csv")
df_origin = df.copy()
df.head()

# %% [markdown]
# Data cleaning, processing and transformation done:
# - renamed column names
# - removal of columns with more than 40% null values
# - removal of rows with more than 50% null values
# - median imputation for null values
# - transformation of features to fix skewness issue

# %%
def df_cleaning(df):
    X, y = get_Xy(df)
    X_imputed, y = med_impute(X, y)
    X_scaled_df = normalise(X_imputed)
    y_df = pd.DataFrame(y)

    X_scaled_df.reset_index(drop=True, inplace=True)
    y_df.reset_index(drop=True, inplace=True)

    df_concat = pd.concat([X_scaled_df, y_df], axis=1)
    df_concat["class"] = df_concat["class"].astype(int)
    # result_df = map_class_labels(df_concat)
    return df_concat

# %%
df.columns = columns
df_cleaned = df_cleaning(df)
df_cube_root_transformed = cube_root_transform(df_cleaned)
df = df_cube_root_transformed

# %%
print(f"Original df shape: {df_origin.shape}")
print(f"Processed df shape: {df.shape}")
df.head()

# %%
# save the processed dataframe as a pickle file
df_to_share = df.copy()
df_to_share.to_pickle("df_to_share.pkl")
